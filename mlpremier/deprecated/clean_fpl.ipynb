# %%
import os
import pandas as pd
from fuzzywuzzy import process
import warnings
from urllib.parse import unquote   #for cleanup of bad folder player names from encoded URLS
import re

# %% [markdown]
# ### Helper Func for Cleaning Player Folder Names for Fuzzy Match

# %%
def decode_url(url):
    # Define a regular expression pattern to match URL-encoded sequences
    pattern = re.compile('%[0-9a-fA-F]{2}')

    # Use a lambda function to replace each match with its decoded equivalent
    decoded_url = pattern.sub(lambda x: unquote(x.group(0)), url)

    return decoded_url

# %% [markdown]
# ## Grab Player Metadata

# %%
def create_player_meta_csv(season:str, 
                           save_dir:str=os.path.join('clean_data', 'meta')):
    """ 
    Create a csv of player metadata.

    :param str season: Which season of EPL data to process metadata for. Should 
        follow the format 20XX-X(X+1).
    :param str save_dir: path within repo to desired data folder for the metadata
      /path/to/data

    :returns: Nothing
    :rtype: None
    """
    RAW_DATA_DIR = 'raw_data'
    meta_data_list = []

    # Check if raw_data/season/gws exists
    season_dir = os.path.join(RAW_DATA_DIR, season, 'gws')
    if not os.path.exists(season_dir):
        print(f"No data found for {season}/gws. Exiting.")
        return

    # Iterate through all CSV files in gws folder
    for filename in os.listdir(season_dir):
        if filename.endswith(".csv"):
            csv_path = os.path.join(season_dir, filename)
            df = pd.read_csv(csv_path)
            df = df.loc[:,['name', 'position', 'team']]

            meta_data_list.append(df)

    # Concatenate all gw metadata (we do this because players may transfer
    # in and out of the league)
    meta_data_df = pd.concat(meta_data_list, axis=0, ignore_index=True)
    meta_data_df = meta_data_df.drop_duplicates(subset=['name'], keep='first')
    
    # Check if 'name', 'position', 'team' are consistent for each 'name'
    #assert meta_data_df.groupby('name')['position'].nunique().eq(1).all()
    #assert meta_data_df.groupby('name')['team'].nunique().eq(1).all()

    # Write the cleaned dataframe to a CSV file
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    save_path = os.path.join(save_dir, f'player_meta_{season}.csv')
    meta_data_df.to_csv(save_path, index=False)
    print(f"Player metadata saved to {save_path}")

    return

# %% [markdown]
# ## Reorder and Clean Cols

# %%
def reorder_and_limit_gwdata_cols(df: pd.DataFrame) -> pd.DataFrame:
    """ 
    Reorders and limits columns of the provided dataframe to the following 
    format:

    cols = name, position, team, opponent_team, minutes, goals_scored, assists, 
    goals_conceded, clean_sheets, bps, yellow_cards, red_cards, own_goals, 
    saves, penalties_missed, penalties_saved, ict_index, influence, creativity, 
    threat, was_home, total_points 
    """
    df = df.copy()
    # Define the desired column order
    desired_cols = ['name', 'position', 'team', 'opponent_team', 'minutes', 
                    'goals_scored', 'assists', 'goals_conceded', 'clean_sheets', 
                    'bps', 'yellow_cards', 'red_cards', 'own_goals', 'saves', 
                    'penalties_missed', 'penalties_saved', 'ict_index', 
                    'influence', 'creativity', 'threat', 'was_home', 
                    'total_points']

    # Reorder and limit the columns
    df = df[desired_cols]

    return df

def fill_in_opponent_team(df: pd.DataFrame, season: str = '2020-21') -> pd.DataFrame:
    """ 
    Fills in the actual opponent team name from the team ID.

    The `master_team_list.csv` file must be downloaded (see `get_master_team_list`
    in `scrape_fpl_data`).
    """
    df = df.copy() 
    
    CLEAN_DATA_DIR = 'clean_data'
    MASTER_TEAM_LIST_PATH = os.path.join(CLEAN_DATA_DIR, 'master_team_list.csv')

    # Load the master_team_list.csv
    master_team_list = pd.read_csv(MASTER_TEAM_LIST_PATH)

    # Create a mapping dictionary using both 'season' and 'team' columns
    mapping_df = master_team_list[(master_team_list['season'] == season)][['team', 'team_name']]
    team_mapping = dict(list(zip(mapping_df['team'], mapping_df['team_name'])))
    #print(team_mapping)

    # Map the opponent_team column using the created mapping
    df['opponent_team'] = df['opponent_team'].apply(lambda team: team_mapping[team])
    
    return df

# %%
def clean_player_data(season: str, 
                    save_dir: str = os.path.join('clean_data'),
                    verbose:bool = False):
    """
    Appends player metadata into player gw-by-gw CSVs. Also cleans player data 
    cols.

    :param str season: Which season of EPL data to process metadata for. Should 
        follow the format 20XX-X(X+1).
    :param str save_dir: path within repo to desired data folder for the metadata
        /path/to/data

    :returns: Nothing
    :rtype: None
    """
    RAW_DATA_DIR = 'raw_data'
    PLAYER_META_CSV_PATH = os.path.join('clean_data', 'meta', f'player_meta_{season}.csv')

    # Load player metadata CSV
    player_meta_df = pd.read_csv(PLAYER_META_CSV_PATH)

    # Iterate through all player_name_folders in the raw_data/players directory
    player_dirs = [f for f in os.listdir(os.path.join(RAW_DATA_DIR, season, 'players')) 
                   if os.path.isdir(os.path.join(RAW_DATA_DIR, season, 'players', f))]
    
    used_names = []

    for player_folder in player_dirs:
        player_name = decode_url(player_folder)
        
        if verbose:
            print(f"Appending metadata via fuzzy match for player: \n{player_folder}\n")
        player_folder_path = os.path.join(RAW_DATA_DIR, season, 'players', player_folder)
        player_csv_path = os.path.join(player_folder_path, 'gw.csv')

        # Load player gw CSV
        if verbose:
            print(f"Reading player data for {player_csv_path}")
        player_gw_df = pd.read_csv(player_csv_path)

        # Fuzzy match based on the closest name in PLAYER_META_CSV
        # with player name extracted via raw data player directory name. 
        # column name to match on is 'name'.
        matches = process.extractOne(player_name.replace('_', ' '), 
                                     player_meta_df['name'])
        top_match = matches[0]

        if top_match in used_names:
            warnings.warn(("Attempted to assign an already matched" 
                          f"player name. Player Folder: {player_folder}." 
                          f"Top Match: {matches[0]}. Skipping this player."))
            continue
        else:
            player_metadata = player_meta_df[player_meta_df['name'] == matches[0]]

            # Append player_metadata columns to player_gw_df
            for col in player_metadata.columns:
                player_gw_df[col] = player_metadata[col].values[0]

            #Clean up player_gw_df columns
            player_gw_df = reorder_and_limit_gwdata_cols(player_gw_df)

            #Fill in Opponent Team
            player_gw_df = fill_in_opponent_team(player_gw_df)

            # Save the updated player_gw_df to the appropriate path
            full_save_dir = os.path.join(save_dir, season, 'players', player_name)
            if not os.path.exists(full_save_dir):
                os.makedirs(full_save_dir, exist_ok=True)


            if verbose: 
                print(f"Saving appended player data to: {full_save_dir}")
            player_gw_df.to_csv(os.path.join(full_save_dir, 'gw.csv'), 
                                index=False)
            
            # Mark the player name as used
            used_names.append(top_match)

    return

# %% [markdown]
# ## Organize Player Data by Position

# %%
def organize_data_by_pos(data_dir: str,
                         verbose: bool = False):
    """
    Organizes player data by position, creating new folders for GKP, DEF, MID, FWD.

    :param str data_dir: Path to the top-level directory containing season and player data.

    :returns: None
    :rtype: None
    """
    POSITIONS = ['GK', 'DEF', 'MID', 'FWD']

    unique_positions = set()

    # Iterate through all seasons (top-level folders)
    top_level_folders = os.listdir(data_dir)
    season_folders = [folder for folder in top_level_folders if not folder == 'meta']
    for season_folder in season_folders:
        season_path = os.path.join(data_dir, season_folder)

        if os.path.isdir(season_path):
            # Iterate through all players within each season
            players_path = os.path.join(season_path, 'players')
            for player_folder in os.listdir(players_path):
                player_path = os.path.join(season_path, 'players', player_folder)

                if os.path.isdir(player_path):
                    # Read in the .csv file in the player's folder
                    player_csv = os.path.join(player_path, "gw.csv")

                    if os.path.isfile(player_csv):
                        player_data = pd.read_csv(player_csv)
                        position = player_data.loc[0, 'position']

                        # Place each player file back into position/season/playername/gw.csv
                        player_pos_folder = os.path.join(season_path, position)
                        os.makedirs(os.path.join(player_pos_folder, player_folder), exist_ok=True)
                        new_player_csv = os.path.join(player_pos_folder, player_folder, "gw.csv")

                        if verbose: 
                            print(f'Copying {player_csv} into {new_player_csv}')
                        player_data.to_csv(new_player_csv, index=False)

    return

# %%
create_player_meta_csv('2020-21')
clean_player_data('2020-21')
# Out:
# Player metadata saved to clean_data/meta/player_meta_2020-21.csv
# /var/folders/1h/lbnzt8g120v24tjmpg9439ww0000gn/T/ipykernel_8287/268396204.py:49: UserWarning: Attempted to assign an already matchedplayer name. Player Folder: Ben_Davies_395.Top Match: Ben Davies. Skipping this player.
#   warnings.warn(("Attempted to assign an already matched"

# %%
create_player_meta_csv('2021-22')
clean_player_data('2021-22')
# Out:
# Player metadata saved to clean_data/meta/player_meta_2021-22.csv
# /var/folders/1h/lbnzt8g120v24tjmpg9439ww0000gn/T/ipykernel_8287/268396204.py:49: UserWarning: Attempted to assign an already matchedplayer name. Player Folder: Ben_Davies_248.Top Match: Ben Davies. Skipping this player.
#   warnings.warn(("Attempted to assign an already matched"
# /var/folders/1h/lbnzt8g120v24tjmpg9439ww0000gn/T/ipykernel_8287/268396204.py:49: UserWarning: Attempted to assign an already matchedplayer name. Player Folder: Álvaro_Fernández_728.Top Match: Álvaro Fernández. Skipping this player.
#   warnings.warn(("Attempted to assign an already matched"

# %%
organize_data_by_pos('clean_data', verbose=True)
# Out:
# Copying clean_data/2021-22/players/Nathaniel_Clyne_493/gw.csv into clean_data/2021-22/DEF/Nathaniel_Clyne_493/gw.csv
# Copying clean_data/2021-22/players/Jarell_Quansah_660/gw.csv into clean_data/2021-22/DEF/Jarell_Quansah_660/gw.csv
# Copying clean_data/2021-22/players/Shane_Duffy_56/gw.csv into clean_data/2021-22/DEF/Shane_Duffy_56/gw.csv
# Copying clean_data/2021-22/players/Bryan_Gil Salvatierra_487/gw.csv into clean_data/2021-22/MID/Bryan_Gil Salvatierra_487/gw.csv
# Copying clean_data/2021-22/players/Tariqe_Fosu-Henry_79/gw.csv into clean_data/2021-22/MID/Tariqe_Fosu-Henry_79/gw.csv
# Copying clean_data/2021-22/players/Bruno_Guimarães Rodriguez Moura_697/gw.csv into clean_data/2021-22/MID/Bruno_Guimarães Rodriguez Moura_697/gw.csv
# Copying clean_data/2021-22/players/Moussa_Djenepo_350/gw.csv into clean_data/2021-22/MID/Moussa_Djenepo_350/gw.csv
# Copying clean_data/2021-22/players/Josh_Martin_330/gw.csv into clean_data/2021-22/MID/Josh_Martin_330/gw.csv
# Copying clean_data/2021-22/players/Ben_Mee_106/gw.csv into clean_data/2021-22/DEF/Ben_Mee_106/gw.csv
# Copying clean_data/2021-22/players/Florin_Andone_500/gw.csv into clean_data/2021-22/FWD/Florin_Andone_500/gw.csv
# Copying clean_data/2021-22/players/Isaac_Price_718/gw.csv into clean_data/2021-22/MID/Isaac_Price_718/gw.csv
# Copying clean_data/2021-22/players/Jan_Bednarek_343/gw.csv into clean_data/2021-22/DEF/Jan_Bednarek_343/gw.csv
# Copying clean_data/2021-22/players/Daniel_Amartey_208/gw.csv into clean_data/2021-22/DEF/Daniel_Amartey_208/gw.csv
# Copying clean_data/2021-22/players/Roberto_Firmino_228/gw.csv into clean_data/2021-22/FWD/Roberto_Firmino_228/gw.csv
# Copying clean_data/2021-22/players/Jamie_Vardy_205/gw.csv into clean_data/2021-22/FWD/Jamie_Vardy_205/gw.csv
# Copying clean_data/2021-22/players/Finley_Stevens_569/gw.csv into clean_data/2021-22/DEF/Finley_Stevens_569/gw.csv
# Copying clean_data/2021-22/players/Onel_Hernández_320/gw.csv into clean_data/2021-22/MID/Onel_Hernández_320/gw.csv
# Copying clean_data/2021-22/players/Héctor Junior_Firpo Adames_463/gw.csv into clean_data/2021-22/DEF/Héctor Junior_Firpo Adames_463/gw.csv
# Copying clean_data/2021-22/players/Dwight_Gayle_300/gw.csv into clean_data/2021-22/FWD/Dwight_Gayle_300/gw.csv
# Copying clean_data/2021-22/players/Jay_Rodriguez_104/gw.csv into clean_data/2021-22/FWD/Jay_Rodriguez_104/gw.csv
# Copying clean_data/2021-22/players/Malang_Sarr_501/gw.csv into clean_data/2021-22/DEF/Malang_Sarr_501/gw.csv
# Copying clean_data/2021-22/players/Jordan_Hugill_322/gw.csv into clean_data/2021-22/FWD/Jordan_Hugill_322/gw.csv
# Copying clean_data/2021-22/players/Conrad_Egan-Riley_651/gw.csv into clean_data/2021-22/DEF/Conrad_Egan-Riley_651/gw.csv
# Copying clean_data/2021-22/players/Kristoffer_Ajer_483/gw.csv into clean_data/2021-22/DEF/Kristoffer_Ajer_483/gw.csv
# Copying clean_data/2021-22/players/Nathan_Aké_258/gw.csv into clean_data/2021-22/DEF/Nathan_Aké_258/gw.csv
# Copying clean_data/2021-22/players/Christian_Pulisic_137/gw.csv into clean_data/2021-22/MID/Christian_Pulisic_137/gw.csv
# Copying clean_data/2021-22/players/Charlie_Savage_737/gw.csv into clean_data/2021-22/MID/Charlie_Savage_737/gw.csv
# Copying clean_data/2021-22/players/Winston_Reid_410/gw.csv into clean_data/2021-22/DEF/Winston_Reid_410/gw.csv
# Copying clean_data/2021-22/players/Kgaogelo_Chauke_680/gw.csv into clean_data/2021-22/MID/Kgaogelo_Chauke_680/gw.csv
# Copying clean_data/2021-22/players/Emerson_Palmieri dos Santos_539/gw.csv into clean_data/2021-22/DEF/Emerson_Palmieri dos Santos_539/gw.csv
# Copying clean_data/2021-22/players/Craig_Cathcart_379/gw.csv into clean_data/2021-22/DEF/Craig_Cathcart_379/gw.csv
# Copying clean_data/2021-22/players/Joseph_Gomez_238/gw.csv into clean_data/2021-22/DEF/Joseph_Gomez_238/gw.csv
# Copying clean_data/2021-22/players/Richarlison_de Andrade_180/gw.csv into clean_data/2021-22/FWD/Richarlison_de Andrade_180/gw.csv
# Copying clean_data/2021-22/players/Angelo_Ogbonna_409/gw.csv into clean_data/2021-22/DEF/Angelo_Ogbonna_409/gw.csv
# Copying clean_data/2021-22/players/Tino_Livramento_491/gw.csv into clean_data/2021-22/DEF/Tino_Livramento_491/gw.csv
# Copying clean_data/2021-22/players/Kai_Havertz_141/gw.csv into clean_data/2021-22/MID/Kai_Havertz_141/gw.csv
# Copying clean_data/2021-22/players/Emerson Aparecido_Leite de Souza Junior_588/gw.csv into clean_data/2021-22/DEF/Emerson Aparecido_Leite de Souza Junior_588/gw.csv
# Copying clean_data/2021-22/players/Philippe_Coutinho Correia_681/gw.csv into clean_data/2021-22/MID/Philippe_Coutinho Correia_681/gw.csv
# Copying clean_data/2021-22/players/Jeffrey_Schlupp_155/gw.csv into clean_data/2021-22/MID/Jeffrey_Schlupp_155/gw.csv
# Copying clean_data/2021-22/players/Emiliano_Buendía Stati_43/gw.csv into clean_data/2021-22/MID/Emiliano_Buendía Stati_43/gw.csv
# Copying clean_data/2021-22/players/Cheikhou_Kouyaté_150/gw.csv into clean_data/2021-22/DEF/Cheikhou_Kouyaté_150/gw.csv
# Copying clean_data/2021-22/players/Shandon_Baptiste_499/gw.csv into clean_data/2021-22/MID/Shandon_Baptiste_499/gw.csv
# Copying clean_data/2021-22/players/James_Ward-Prowse_341/gw.csv into clean_data/2021-22/MID/James_Ward-Prowse_341/gw.csv
# Copying clean_data/2021-22/players/Rodrigo_Bentancur_702/gw.csv into clean_data/2021-22/MID/Rodrigo_Bentancur_702/gw.csv
# Copying clean_data/2021-22/players/Martin_Ødegaard_558/gw.csv into clean_data/2021-22/MID/Martin_Ødegaard_558/gw.csv
# Copying clean_data/2021-22/players/Tyrone_Mings_38/gw.csv into clean_data/2021-22/DEF/Tyrone_Mings_38/gw.csv
# Copying clean_data/2021-22/players/Jack_Stephens_338/gw.csv into clean_data/2021-22/DEF/Jack_Stephens_338/gw.csv
# Copying clean_data/2021-22/players/Kasper_Schmeichel_200/gw.csv into clean_data/2021-22/GK/Kasper_Schmeichel_200/gw.csv
# Copying clean_data/2021-22/players/Abdoulaye_Doucouré_173/gw.csv into clean_data/2021-22/MID/Abdoulaye_Doucouré_173/gw.csv
# Copying clean_data/2021-22/players/Wilfried_Zaha_154/gw.csv into clean_data/2021-22/MID/Wilfried_Zaha_154/gw.csv
# Copying clean_data/2021-22/players/Daniel_Bachmann_389/gw.csv into clean_data/2021-22/GK/Daniel_Bachmann_389/gw.csv
# Copying clean_data/2021-22/players/Declan_Rice_421/gw.csv into clean_data/2021-22/MID/Declan_Rice_421/gw.csv
# Copying clean_data/2021-22/players/Fabio_Silva_445/gw.csv into clean_data/2021-22/FWD/Fabio_Silva_445/gw.csv
# Copying clean_data/2021-22/players/Joseph_Willock_19/gw.csv into clean_data/2021-22/MID/Joseph_Willock_19/gw.csv
# Copying clean_data/2021-22/players/Hannibal_Mejbri_706/gw.csv into clean_data/2021-22/MID/Hannibal_Mejbri_706/gw.csv
# Copying clean_data/2021-22/players/João Pedro Cavaco_Cancelo_256/gw.csv into clean_data/2021-22/DEF/João Pedro Cavaco_Cancelo_256/gw.csv
# Copying clean_data/2021-22/players/Imrân_Louza_403/gw.csv into clean_data/2021-22/MID/Imrân_Louza_403/gw.csv
# Copying clean_data/2021-22/players/Victor_Lindelöf_284/gw.csv into clean_data/2021-22/DEF/Victor_Lindelöf_284/gw.csv
# Copying clean_data/2021-22/players/Samuel_Edozie_508/gw.csv into clean_data/2021-22/MID/Samuel_Edozie_508/gw.csv
# Copying clean_data/2021-22/players/Alex_Iwobi_174/gw.csv into clean_data/2021-22/MID/Alex_Iwobi_174/gw.csv
# Copying clean_data/2021-22/players/Dion_Sanderson_686/gw.csv into clean_data/2021-22/DEF/Dion_Sanderson_686/gw.csv
# Copying clean_data/2021-22/players/Owen_Otasowie_442/gw.csv into clean_data/2021-22/MID/Owen_Otasowie_442/gw.csv
# Copying clean_data/2021-22/players/Marvelous_Nakamba_41/gw.csv into clean_data/2021-22/MID/Marvelous_Nakamba_41/gw.csv
# Copying clean_data/2021-22/players/Sergio_Reguilón_370/gw.csv into clean_data/2021-22/DEF/Sergio_Reguilón_370/gw.csv
# Copying clean_data/2021-22/players/Moussa_Sissoko_354/gw.csv into clean_data/2021-22/MID/Moussa_Sissoko_354/gw.csv
# Copying clean_data/2021-22/players/Alex_Kirk_730/gw.csv into clean_data/2021-22/DEF/Alex_Kirk_730/gw.csv
# Copying clean_data/2021-22/players/Saúl_Ñíguez_592/gw.csv into clean_data/2021-22/MID/Saúl_Ñíguez_592/gw.csv
# Copying clean_data/2021-22/players/Nicolas_Pépé_17/gw.csv into clean_data/2021-22/MID/Nicolas_Pépé_17/gw.csv
# Copying clean_data/2021-22/players/Christian_Eriksen_699/gw.csv into clean_data/2021-22/MID/Christian_Eriksen_699/gw.csv
# Copying clean_data/2021-22/players/Charlie_Taylor_113/gw.csv into clean_data/2021-22/DEF/Charlie_Taylor_113/gw.csv
# Copying clean_data/2021-22/players/Martin_Dubravka_295/gw.csv into clean_data/2021-22/GK/Martin_Dubravka_295/gw.csv
# Copying clean_data/2021-22/players/Christian_Kabasele_384/gw.csv into clean_data/2021-22/DEF/Christian_Kabasele_384/gw.csv
# Copying clean_data/2021-22/players/Alex_Kral_589/gw.csv into clean_data/2021-22/MID/Alex_Kral_589/gw.csv
# Copying clean_data/2021-22/players/Phil_Foden_265/gw.csv into clean_data/2021-22/MID/Phil_Foden_265/gw.csv
# Copying clean_data/2021-22/players/Francisco Jorge_Tomás Oliveira_689/gw.csv into clean_data/2021-22/MID/Francisco Jorge_Tomás Oliveira_689/gw.csv
# Copying clean_data/2021-22/players/Anthony_Gordon_503/gw.csv into clean_data/2021-22/MID/Anthony_Gordon_503/gw.csv
# Copying clean_data/2021-22/players/Robin_Olsen_691/gw.csv into clean_data/2021-22/GK/Robin_Olsen_691/gw.csv
# Copying clean_data/2021-22/players/Jason_Steele_54/gw.csv into clean_data/2021-22/GK/Jason_Steele_54/gw.csv
# Copying clean_data/2021-22/players/Luke_Thomas_219/gw.csv into clean_data/2021-22/DEF/Luke_Thomas_219/gw.csv
# Copying clean_data/2021-22/players/Ainsley_Maitland-Niles_13/gw.csv into clean_data/2021-22/MID/Ainsley_Maitland-Niles_13/gw.csv
# Copying clean_data/2021-22/players/Tiago_Çukur_732/gw.csv into clean_data/2021-22/FWD/Tiago_Çukur_732/gw.csv
# Copying clean_data/2021-22/players/Carney_Chukwuemeka_526/gw.csv into clean_data/2021-22/MID/Carney_Chukwuemeka_526/gw.csv
# Copying clean_data/2021-22/players/Will_Hughes_386/gw.csv into clean_data/2021-22/MID/Will_Hughes_386/gw.csv
# Copying clean_data/2021-22/players/Aaron_Ramsdale_559/gw.csv into clean_data/2021-22/GK/Aaron_Ramsdale_559/gw.csv
# Copying clean_data/2021-22/players/Grant_Hanley_319/gw.csv into clean_data/2021-22/DEF/Grant_Hanley_319/gw.csv
# Copying clean_data/2021-22/players/Jamie_Shackleton_197/gw.csv into clean_data/2021-22/MID/Jamie_Shackleton_197/gw.csv
# Copying clean_data/2021-22/players/Charlie_Goode_87/gw.csv into clean_data/2021-22/DEF/Charlie_Goode_87/gw.csv
# Copying clean_data/2021-22/players/Divock_Origi_235/gw.csv into clean_data/2021-22/FWD/Divock_Origi_235/gw.csv
# Copying clean_data/2021-22/players/Mathew_Ryan_65/gw.csv into clean_data/2021-22/GK/Mathew_Ryan_65/gw.csv
# Copying clean_data/2021-22/players/Brandon_Austin_659/gw.csv into clean_data/2021-22/GK/Brandon_Austin_659/gw.csv
# Copying clean_data/2021-22/players/Ben_White_67/gw.csv into clean_data/2021-22/DEF/Ben_White_67/gw.csv
# Copying clean_data/2021-22/players/Sam_Greenwood_550/gw.csv into clean_data/2021-22/FWD/Sam_Greenwood_550/gw.csv
# Copying clean_data/2021-22/players/Erik_Pieters_100/gw.csv into clean_data/2021-22/DEF/Erik_Pieters_100/gw.csv
# Copying clean_data/2021-22/players/Robert_Sánchez_69/gw.csv into clean_data/2021-22/GK/Robert_Sánchez_69/gw.csv
# Copying clean_data/2021-22/players/Matthew_Cash_44/gw.csv into clean_data/2021-22/DEF/Matthew_Cash_44/gw.csv
# Copying clean_data/2021-22/players/Oghenekaro Peter_Etebo_467/gw.csv into clean_data/2021-22/MID/Oghenekaro Peter_Etebo_467/gw.csv
# Copying clean_data/2021-22/players/James_Tomkins_147/gw.csv into clean_data/2021-22/DEF/James_Tomkins_147/gw.csv
# Copying clean_data/2021-22/players/Michael_Obafemi_348/gw.csv into clean_data/2021-22/FWD/Michael_Obafemi_348/gw.csv
# Copying clean_data/2021-22/players/Will_Norris_114/gw.csv into clean_data/2021-22/GK/Will_Norris_114/gw.csv
# Copying clean_data/2021-22/players/Mattéo_Guendouzi_25/gw.csv into clean_data/2021-22/MID/Mattéo_Guendouzi_25/gw.csv
# Copying clean_data/2021-22/players/Raphaël_Varane_555/gw.csv into clean_data/2021-22/DEF/Raphaël_Varane_555/gw.csv
# Copying clean_data/2021-22/players/Bernard_Anício Caldeira Duarte_167/gw.csv into clean_data/2021-22/MID/Bernard_Anício Caldeira Duarte_167/gw.csv
# Copying clean_data/2021-22/players/Daniel_Chesters_710/gw.csv into clean_data/2021-22/MID/Daniel_Chesters_710/gw.csv
# Copying clean_data/2021-22/players/Tommy_Doyle_566/gw.csv into clean_data/2021-22/MID/Tommy_Doyle_566/gw.csv
# Copying clean_data/2021-22/players/Mbwana Ally_Samatta_48/gw.csv into clean_data/2021-22/FWD/Mbwana Ally_Samatta_48/gw.csv
# Copying clean_data/2021-22/players/Francisco_Casilla Cortés_183/gw.csv into clean_data/2021-22/GK/Francisco_Casilla Cortés_183/gw.csv
# Copying clean_data/2021-22/players/Rúnar Alex_Rúnarsson_2/gw.csv into clean_data/2021-22/GK/Rúnar Alex_Rúnarsson_2/gw.csv
# Copying clean_data/2021-22/players/Troy_Deeney_380/gw.csv into clean_data/2021-22/FWD/Troy_Deeney_380/gw.csv
# Copying clean_data/2021-22/players/Jamaal_Lascelles_299/gw.csv into clean_data/2021-22/DEF/Jamaal_Lascelles_299/gw.csv
# Copying clean_data/2021-22/players/Brandon_Williams_290/gw.csv into clean_data/2021-22/DEF/Brandon_Williams_290/gw.csv
# Copying clean_data/2021-22/players/Alexandre_Lacazette_6/gw.csv into clean_data/2021-22/FWD/Alexandre_Lacazette_6/gw.csv
# Copying clean_data/2021-22/players/Ashley_Westwood_107/gw.csv into clean_data/2021-22/MID/Ashley_Westwood_107/gw.csv
# Copying clean_data/2021-22/players/Thomas_Dickson-Peters_649/gw.csv into clean_data/2021-22/FWD/Thomas_Dickson-Peters_649/gw.csv
# Copying clean_data/2021-22/players/Paul_Pogba_272/gw.csv into clean_data/2021-22/MID/Paul_Pogba_272/gw.csv
# Copying clean_data/2021-22/players/Ethan_Pinnock_91/gw.csv into clean_data/2021-22/DEF/Ethan_Pinnock_91/gw.csv
# Copying clean_data/2021-22/players/Trent_Alexander-Arnold_237/gw.csv into clean_data/2021-22/DEF/Trent_Alexander-Arnold_237/gw.csv
# Copying clean_data/2021-22/players/Christian_Benteke_149/gw.csv into clean_data/2021-22/FWD/Christian_Benteke_149/gw.csv
# Copying clean_data/2021-22/players/Eric_Dier_361/gw.csv into clean_data/2021-22/DEF/Eric_Dier_361/gw.csv
# Copying clean_data/2021-22/players/Oleksandr_Zinchenko_264/gw.csv into clean_data/2021-22/DEF/Oleksandr_Zinchenko_264/gw.csv
# Copying clean_data/2021-22/players/Frederico_Rodrigues de Paula Santos_274/gw.csv into clean_data/2021-22/MID/Frederico_Rodrigues de Paula Santos_274/gw.csv
# Copying clean_data/2021-22/players/Gabriel Teodoro_Martinelli Silva_26/gw.csv into clean_data/2021-22/MID/Gabriel Teodoro_Martinelli Silva_26/gw.csv
# Copying clean_data/2021-22/players/Daniel_James_287/gw.csv into clean_data/2021-22/MID/Daniel_James_287/gw.csv
# Copying clean_data/2021-22/players/Jed_Steer_28/gw.csv into clean_data/2021-22/GK/Jed_Steer_28/gw.csv
# Copying clean_data/2021-22/players/William_Smallbone_347/gw.csv into clean_data/2021-22/MID/William_Smallbone_347/gw.csv
# Copying clean_data/2021-22/players/Toti António_Gomes_685/gw.csv into clean_data/2021-22/DEF/Toti António_Gomes_685/gw.csv
# Copying clean_data/2021-22/players/Serge_Aurier_358/gw.csv into clean_data/2021-22/DEF/Serge_Aurier_358/gw.csv
# Copying clean_data/2021-22/players/Tammy_Abraham_136/gw.csv into clean_data/2021-22/FWD/Tammy_Abraham_136/gw.csv
# Copying clean_data/2021-22/players/Przemyslaw_Placheta_328/gw.csv into clean_data/2021-22/MID/Przemyslaw_Placheta_328/gw.csv
# Copying clean_data/2021-22/players/Ben_Wilmot_401/gw.csv into clean_data/2021-22/DEF/Ben_Wilmot_401/gw.csv
# Copying clean_data/2021-22/players/Domingos_Quina_397/gw.csv into clean_data/2021-22/MID/Domingos_Quina_397/gw.csv
# Copying clean_data/2021-22/players/Kevin_De Bruyne_251/gw.csv into clean_data/2021-22/MID/Kevin_De Bruyne_251/gw.csv
# Copying clean_data/2021-22/players/Lewis_Brunt_646/gw.csv into clean_data/2021-22/MID/Lewis_Brunt_646/gw.csv
# Copying clean_data/2021-22/players/Nampalys_Mendy_203/gw.csv into clean_data/2021-22/MID/Nampalys_Mendy_203/gw.csv
# Copying clean_data/2021-22/players/Josh_Benson_116/gw.csv into clean_data/2021-22/MID/Josh_Benson_116/gw.csv
# Copying clean_data/2021-22/players/Mohamed_Elyounoussi_517/gw.csv into clean_data/2021-22/MID/Mohamed_Elyounoussi_517/gw.csv
# Copying clean_data/2021-22/players/Dan_Burn_58/gw.csv into clean_data/2021-22/DEF/Dan_Burn_58/gw.csv
# Copying clean_data/2021-22/players/Álvaro_Fernández_556/gw.csv into clean_data/2021-22/GK/Álvaro_Fernández_556/gw.csv
# Copying clean_data/2021-22/players/Stuart_Dallas_188/gw.csv into clean_data/2021-22/MID/Stuart_Dallas_188/gw.csv
# Copying clean_data/2021-22/players/Ezri_Konsa Ngoyo_45/gw.csv into clean_data/2021-22/DEF/Ezri_Konsa Ngoyo_45/gw.csv
# Copying clean_data/2021-22/players/Amad_Diallo_636/gw.csv into clean_data/2021-22/MID/Amad_Diallo_636/gw.csv
# Copying clean_data/2021-22/players/Nathan_Patterson_674/gw.csv into clean_data/2021-22/DEF/Nathan_Patterson_674/gw.csv
# Copying clean_data/2021-22/players/Theo_Walcott_332/gw.csv into clean_data/2021-22/MID/Theo_Walcott_332/gw.csv
# Copying clean_data/2021-22/players/Edinson_Cavani_269/gw.csv into clean_data/2021-22/FWD/Edinson_Cavani_269/gw.csv
# Copying clean_data/2021-22/players/Allan_Marques Loureiro_171/gw.csv into clean_data/2021-22/MID/Allan_Marques Loureiro_171/gw.csv
# Copying clean_data/2021-22/players/Alireza_Jahanbakhsh_66/gw.csv into clean_data/2021-22/MID/Alireza_Jahanbakhsh_66/gw.csv
# Copying clean_data/2021-22/players/Odsonne_Edouard_586/gw.csv into clean_data/2021-22/FWD/Odsonne_Edouard_586/gw.csv
# Copying clean_data/2021-22/players/Sead_Kolasinac_11/gw.csv into clean_data/2021-22/DEF/Sead_Kolasinac_11/gw.csv
# Copying clean_data/2021-22/players/Konstantinos_Tsimikas_245/gw.csv into clean_data/2021-22/DEF/Konstantinos_Tsimikas_245/gw.csv
# Copying clean_data/2021-22/players/Leander_Dendoncker_434/gw.csv into clean_data/2021-22/MID/Leander_Dendoncker_434/gw.csv
# Copying clean_data/2021-22/players/Pierre_Lees-Melou_471/gw.csv into clean_data/2021-22/MID/Pierre_Lees-Melou_471/gw.csv
# Copying clean_data/2021-22/players/Andreas_Söndergaard_444/gw.csv into clean_data/2021-22/GK/Andreas_Söndergaard_444/gw.csv
# Copying clean_data/2021-22/players/Folarin_Balogun_530/gw.csv into clean_data/2021-22/FWD/Folarin_Balogun_530/gw.csv
# Copying clean_data/2021-22/players/Neco_Williams_246/gw.csv into clean_data/2021-22/DEF/Neco_Williams_246/gw.csv
# Copying clean_data/2021-22/players/Jarrad_Branthwaite_544/gw.csv into clean_data/2021-22/DEF/Jarrad_Branthwaite_544/gw.csv
# Copying clean_data/2021-22/players/Anwar_El Ghazi_42/gw.csv into clean_data/2021-22/MID/Anwar_El Ghazi_42/gw.csv
# Copying clean_data/2021-22/players/Eric_Bailly_286/gw.csv into clean_data/2021-22/DEF/Eric_Bailly_286/gw.csv
# Copying clean_data/2021-22/players/Pablo_Marí_8/gw.csv into clean_data/2021-22/DEF/Pablo_Marí_8/gw.csv
# Copying clean_data/2021-22/players/Aaron_Wan-Bissaka_288/gw.csv into clean_data/2021-22/DEF/Aaron_Wan-Bissaka_288/gw.csv
# Copying clean_data/2021-22/players/Moise_Kean_564/gw.csv into clean_data/2021-22/FWD/Moise_Kean_564/gw.csv
# Copying clean_data/2021-22/players/Tim_Iroegbunam_638/gw.csv into clean_data/2021-22/MID/Tim_Iroegbunam_638/gw.csv
# Copying clean_data/2021-22/players/Charlie_Whitaker_613/gw.csv into clean_data/2021-22/MID/Charlie_Whitaker_613/gw.csv
# Copying clean_data/2021-22/players/Kurt_Zouma_128/gw.csv into clean_data/2021-22/DEF/Kurt_Zouma_128/gw.csv
# Copying clean_data/2021-22/players/Kwadwo_Baah_405/gw.csv into clean_data/2021-22/MID/Kwadwo_Baah_405/gw.csv
# Copying clean_data/2021-22/players/Jeremy_Ngakia_400/gw.csv into clean_data/2021-22/DEF/Jeremy_Ngakia_400/gw.csv
# Copying clean_data/2021-22/players/James_McAtee_629/gw.csv into clean_data/2021-22/MID/James_McAtee_629/gw.csv
# Copying clean_data/2021-22/players/Ryan_Giles_687/gw.csv into clean_data/2021-22/MID/Ryan_Giles_687/gw.csv
# Copying clean_data/2021-22/players/Cristian_Romero_494/gw.csv into clean_data/2021-22/DEF/Cristian_Romero_494/gw.csv
# Copying clean_data/2021-22/players/Remi_Matthews_561/gw.csv into clean_data/2021-22/GK/Remi_Matthews_561/gw.csv
# Copying clean_data/2021-22/players/Jack_Grealish_33/gw.csv into clean_data/2021-22/MID/Jack_Grealish_33/gw.csv
# Copying clean_data/2021-22/players/Lukasz_Fabianski_408/gw.csv into clean_data/2021-22/GK/Lukasz_Fabianski_408/gw.csv
# Copying clean_data/2021-22/players/Conor_Coventry_522/gw.csv into clean_data/2021-22/MID/Conor_Coventry_522/gw.csv
# Copying clean_data/2021-22/players/Saman_Ghoddos_85/gw.csv into clean_data/2021-22/MID/Saman_Ghoddos_85/gw.csv
# Copying clean_data/2021-22/players/Vicente_Guaita_146/gw.csv into clean_data/2021-22/GK/Vicente_Guaita_146/gw.csv
# Copying clean_data/2021-22/players/Julian_Jeanvier_722/gw.csv into clean_data/2021-22/DEF/Julian_Jeanvier_722/gw.csv
# Copying clean_data/2021-22/players/Joe_White_599/gw.csv into clean_data/2021-22/MID/Joe_White_599/gw.csv
# Copying clean_data/2021-22/players/Hugo_Lloris_353/gw.csv into clean_data/2021-22/GK/Hugo_Lloris_353/gw.csv
# Copying clean_data/2021-22/players/Solomon_March_60/gw.csv into clean_data/2021-22/MID/Solomon_March_60/gw.csv
# Copying clean_data/2021-22/players/Marc_Leonard_654/gw.csv into clean_data/2021-22/MID/Marc_Leonard_654/gw.csv
# Copying clean_data/2021-22/players/Matt_Ritchie_292/gw.csv into clean_data/2021-22/DEF/Matt_Ritchie_292/gw.csv
# Copying clean_data/2021-22/players/Tom_Cleverley_381/gw.csv into clean_data/2021-22/MID/Tom_Cleverley_381/gw.csv
# Copying clean_data/2021-22/players/Filip_Marschall_650/gw.csv into clean_data/2021-22/GK/Filip_Marschall_650/gw.csv
# Copying clean_data/2021-22/players/Tanguy_Ndombele_375/gw.csv into clean_data/2021-22/MID/Tanguy_Ndombele_375/gw.csv
# Copying clean_data/2021-22/players/Seamus_Coleman_165/gw.csv into clean_data/2021-22/DEF/Seamus_Coleman_165/gw.csv
# Copying clean_data/2021-22/players/Callum_Hudson-Odoi_140/gw.csv into clean_data/2021-22/MID/Callum_Hudson-Odoi_140/gw.csv
# Copying clean_data/2021-22/players/Vincent_Angelini_642/gw.csv into clean_data/2021-22/GK/Vincent_Angelini_642/gw.csv
# Copying clean_data/2021-22/players/José Diogo_Dalot Teixeira_510/gw.csv into clean_data/2021-22/DEF/José Diogo_Dalot Teixeira_510/gw.csv
# Copying clean_data/2021-22/players/Juan_Mata_459/gw.csv into clean_data/2021-22/MID/Juan_Mata_459/gw.csv
# Copying clean_data/2021-22/players/Nathan_Collins_451/gw.csv into clean_data/2021-22/DEF/Nathan_Collins_451/gw.csv
# Copying clean_data/2021-22/players/Pablo_Hernández Domínguez_182/gw.csv into clean_data/2021-22/MID/Pablo_Hernández Domínguez_182/gw.csv
# Copying clean_data/2021-22/players/Ryan_Bertrand_473/gw.csv into clean_data/2021-22/DEF/Ryan_Bertrand_473/gw.csv
# Copying clean_data/2021-22/players/Andros_Townsend_482/gw.csv into clean_data/2021-22/MID/Andros_Townsend_482/gw.csv
# Copying clean_data/2021-22/players/Lyanco Evangelista_Silveira Neves Vojnovic_567/gw.csv into clean_data/2021-22/DEF/Lyanco Evangelista_Silveira Neves Vojnovic_567/gw.csv
# Copying clean_data/2021-22/players/Marc_Albrighton_202/gw.csv into clean_data/2021-22/MID/Marc_Albrighton_202/gw.csv
# Copying clean_data/2021-22/players/Yan_Valery_546/gw.csv into clean_data/2021-22/DEF/Yan_Valery_546/gw.csv
# Copying clean_data/2021-22/players/Adrian_Blake_733/gw.csv into clean_data/2021-22/MID/Adrian_Blake_733/gw.csv
# Copying clean_data/2021-22/players/Mark_Noble_406/gw.csv into clean_data/2021-22/MID/Mark_Noble_406/gw.csv
# Copying clean_data/2021-22/players/Andreas_Christensen_133/gw.csv into clean_data/2021-22/DEF/Andreas_Christensen_133/gw.csv
# Copying clean_data/2021-22/players/Ellis_Simms_602/gw.csv into clean_data/2021-22/FWD/Ellis_Simms_602/gw.csv
# Copying clean_data/2021-22/players/Shaqai_Forde_725/gw.csv into clean_data/2021-22/FWD/Shaqai_Forde_725/gw.csv
# Copying clean_data/2021-22/players/Sam_Byram_321/gw.csv into clean_data/2021-22/DEF/Sam_Byram_321/gw.csv
# Copying clean_data/2021-22/players/Johann Berg_Gudmundsson_108/gw.csv into clean_data/2021-22/MID/Johann Berg_Gudmundsson_108/gw.csv
# Copying clean_data/2021-22/players/Wayne_Hennessey_480/gw.csv into clean_data/2021-22/GK/Wayne_Hennessey_480/gw.csv
# Copying clean_data/2021-22/players/Luke_Shaw_275/gw.csv into clean_data/2021-22/DEF/Luke_Shaw_275/gw.csv
# Copying clean_data/2021-22/players/Mohammed_Salisu_351/gw.csv into clean_data/2021-22/DEF/Mohammed_Salisu_351/gw.csv
# Copying clean_data/2021-22/players/Matt_Targett_39/gw.csv into clean_data/2021-22/DEF/Matt_Targett_39/gw.csv
# Copying clean_data/2021-22/players/Jordan_Pickford_170/gw.csv into clean_data/2021-22/GK/Jordan_Pickford_170/gw.csv
# Copying clean_data/2021-22/players/Miguel_Almirón_308/gw.csv into clean_data/2021-22/MID/Miguel_Almirón_308/gw.csv
# Copying clean_data/2021-22/players/Jan_Zamburek_93/gw.csv into clean_data/2021-22/MID/Jan_Zamburek_93/gw.csv
# Copying clean_data/2021-22/players/Lucas_Digne_168/gw.csv into clean_data/2021-22/DEF/Lucas_Digne_168/gw.csv
# Copying clean_data/2021-22/players/Benjamin_Chilwell_135/gw.csv into clean_data/2021-22/DEF/Benjamin_Chilwell_135/gw.csv
# Copying clean_data/2021-22/players/Adam_Forshaw_552/gw.csv into clean_data/2021-22/MID/Adam_Forshaw_552/gw.csv
# Copying clean_data/2021-22/players/André Filipe_Tavares Gomes_172/gw.csv into clean_data/2021-22/MID/André Filipe_Tavares Gomes_172/gw.csv
# Copying clean_data/2021-22/players/Angus_Gunn_448/gw.csv into clean_data/2021-22/GK/Angus_Gunn_448/gw.csv
# Copying clean_data/2021-22/players/Andy_Lonergan_571/gw.csv into clean_data/2021-22/GK/Andy_Lonergan_571/gw.csv
# Copying clean_data/2021-22/players/Darren_Randolph_407/gw.csv into clean_data/2021-22/GK/Darren_Randolph_407/gw.csv
# Copying clean_data/2021-22/players/Heung-Min_Son_359/gw.csv into clean_data/2021-22/MID/Heung-Min_Son_359/gw.csv
# Copying clean_data/2021-22/players/Dale_Stephens_102/gw.csv into clean_data/2021-22/MID/Dale_Stephens_102/gw.csv
# Copying clean_data/2021-22/players/Dennis_Praet_206/gw.csv into clean_data/2021-22/MID/Dennis_Praet_206/gw.csv
# Copying clean_data/2021-22/players/Kelechi_Iheanacho_213/gw.csv into clean_data/2021-22/FWD/Kelechi_Iheanacho_213/gw.csv
# Copying clean_data/2021-22/players/Cameron_Archer_568/gw.csv into clean_data/2021-22/FWD/Cameron_Archer_568/gw.csv
# Copying clean_data/2021-22/players/Davinson_Sánchez_367/gw.csv into clean_data/2021-22/DEF/Davinson_Sánchez_367/gw.csv
# Copying clean_data/2021-22/players/Adam_Lallana_53/gw.csv into clean_data/2021-22/MID/Adam_Lallana_53/gw.csv
# Copying clean_data/2021-22/players/Jesse_Lingard_276/gw.csv into clean_data/2021-22/MID/Jesse_Lingard_276/gw.csv
# Copying clean_data/2021-22/players/Bernardo Mota_Veiga de Carvalho e Silva_261/gw.csv into clean_data/2021-22/MID/Bernardo Mota_Veiga de Carvalho e Silva_261/gw.csv
# Copying clean_data/2021-22/players/José_Malheiro de Sá_475/gw.csv into clean_data/2021-22/GK/José_Malheiro de Sá_475/gw.csv
# Copying clean_data/2021-22/players/Vitaly_Janelt_84/gw.csv into clean_data/2021-22/MID/Vitaly_Janelt_84/gw.csv
# Copying clean_data/2021-22/players/Connor_Roberts_585/gw.csv into clean_data/2021-22/DEF/Connor_Roberts_585/gw.csv
# Copying clean_data/2021-22/players/Jack_Harrison_267/gw.csv into clean_data/2021-22/MID/Jack_Harrison_267/gw.csv
# Copying clean_data/2021-22/players/Jacob_Murphy_304/gw.csv into clean_data/2021-22/MID/Jacob_Murphy_304/gw.csv
# Copying clean_data/2021-22/players/Diego_Llorente_190/gw.csv into clean_data/2021-22/DEF/Diego_Llorente_190/gw.csv
# Copying clean_data/2021-22/players/Rayan_Ait Nouri_470/gw.csv into clean_data/2021-22/DEF/Rayan_Ait Nouri_470/gw.csv
# Copying clean_data/2021-22/players/Rúben Santos_Gato Alves Dias_262/gw.csv into clean_data/2021-22/DEF/Rúben Santos_Gato Alves Dias_262/gw.csv
# Copying clean_data/2021-22/players/Abu_Kamara_715/gw.csv into clean_data/2021-22/FWD/Abu_Kamara_715/gw.csv
# Copying clean_data/2021-22/players/Robert_Street_542/gw.csv into clean_data/2021-22/FWD/Robert_Street_542/gw.csv
# Copying clean_data/2021-22/players/Tyler_Dibling_731/gw.csv into clean_data/2021-22/MID/Tyler_Dibling_731/gw.csv
# Copying clean_data/2021-22/players/Jamal_Baptiste_554/gw.csv into clean_data/2021-22/DEF/Jamal_Baptiste_554/gw.csv
# Copying clean_data/2021-22/players/Alexis_Mac Allister_74/gw.csv into clean_data/2021-22/MID/Alexis_Mac Allister_74/gw.csv
# Copying clean_data/2021-22/players/Michail_Antonio_413/gw.csv into clean_data/2021-22/FWD/Michail_Antonio_413/gw.csv
# Copying clean_data/2021-22/players/Scott_McTominay_285/gw.csv into clean_data/2021-22/MID/Scott_McTominay_285/gw.csv
# Copying clean_data/2021-22/players/Rhys_Williams_247/gw.csv into clean_data/2021-22/DEF/Rhys_Williams_247/gw.csv
# Copying clean_data/2021-22/players/Luke_Ayling_185/gw.csv into clean_data/2021-22/DEF/Luke_Ayling_185/gw.csv
# Copying clean_data/2021-22/players/Michael_Keane_169/gw.csv into clean_data/2021-22/DEF/Michael_Keane_169/gw.csv
# Copying clean_data/2021-22/players/Jonathan_Rowe_648/gw.csv into clean_data/2021-22/MID/Jonathan_Rowe_648/gw.csv
# Copying clean_data/2021-22/players/Mahmoud Ahmed_Ibrahim Hassan_37/gw.csv into clean_data/2021-22/MID/Mahmoud Ahmed_Ibrahim Hassan_37/gw.csv
# Copying clean_data/2021-22/players/Jon_McCracken_666/gw.csv into clean_data/2021-22/GK/Jon_McCracken_666/gw.csv
# Copying clean_data/2021-22/players/Pascal_Groß_55/gw.csv into clean_data/2021-22/MID/Pascal_Groß_55/gw.csv
# Copying clean_data/2021-22/players/Pontus_Jansson_76/gw.csv into clean_data/2021-22/DEF/Pontus_Jansson_76/gw.csv
# Copying clean_data/2021-22/players/Yerson_Mosquera Valdelamar_446/gw.csv into clean_data/2021-22/DEF/Yerson_Mosquera Valdelamar_446/gw.csv
# Copying clean_data/2021-22/players/Max_Aarons_326/gw.csv into clean_data/2021-22/DEF/Max_Aarons_326/gw.csv
# Copying clean_data/2021-22/players/Nick_Pope_112/gw.csv into clean_data/2021-22/GK/Nick_Pope_112/gw.csv
# Copying clean_data/2021-22/players/Cédric_Soares_5/gw.csv into clean_data/2021-22/DEF/Cédric_Soares_5/gw.csv
# Copying clean_data/2021-22/players/Kaine_Hayden_684/gw.csv into clean_data/2021-22/DEF/Kaine_Hayden_684/gw.csv
# Copying clean_data/2021-22/players/Ademola_Lookman_587/gw.csv into clean_data/2021-22/MID/Ademola_Lookman_587/gw.csv
# Copying clean_data/2021-22/players/Hakim_Ziyech_131/gw.csv into clean_data/2021-22/MID/Hakim_Ziyech_131/gw.csv
# Copying clean_data/2021-22/players/Christos_Tzolis_528/gw.csv into clean_data/2021-22/MID/Christos_Tzolis_528/gw.csv
# Copying clean_data/2021-22/players/Adam_Masina_390/gw.csv into clean_data/2021-22/DEF/Adam_Masina_390/gw.csv
# Copying clean_data/2021-22/players/Patson_Daka_455/gw.csv into clean_data/2021-22/FWD/Patson_Daka_455/gw.csv
# Copying clean_data/2021-22/players/Adam_Webster_61/gw.csv into clean_data/2021-22/DEF/Adam_Webster_61/gw.csv
# Copying clean_data/2021-22/players/James_Morris_633/gw.csv into clean_data/2021-22/DEF/James_Morris_633/gw.csv
# Copying clean_data/2021-22/players/Jacob_Sørensen_327/gw.csv into clean_data/2021-22/DEF/Jacob_Sørensen_327/gw.csv
# Copying clean_data/2021-22/players/Donny_van de Beek_282/gw.csv into clean_data/2021-22/MID/Donny_van de Beek_282/gw.csv
# Copying clean_data/2021-22/players/Liam_McCarron_576/gw.csv into clean_data/2021-22/MID/Liam_McCarron_576/gw.csv
# Copying clean_data/2021-22/players/Takehiro_Tomiyasu_590/gw.csv into clean_data/2021-22/DEF/Takehiro_Tomiyasu_590/gw.csv
# Copying clean_data/2021-22/players/Ricardo Domingos_Barbosa Pereira_207/gw.csv into clean_data/2021-22/DEF/Ricardo Domingos_Barbosa Pereira_207/gw.csv
# Copying clean_data/2021-22/players/Jonathan_Tomkinson_643/gw.csv into clean_data/2021-22/DEF/Jonathan_Tomkinson_643/gw.csv
# Copying clean_data/2021-22/players/Luke_Cundle_547/gw.csv into clean_data/2021-22/MID/Luke_Cundle_547/gw.csv
# Copying clean_data/2021-22/players/Pierre-Emerick_Aubameyang_4/gw.csv into clean_data/2021-22/FWD/Pierre-Emerick_Aubameyang_4/gw.csv
# Copying clean_data/2021-22/players/Lewis_Bate_624/gw.csv into clean_data/2021-22/MID/Lewis_Bate_624/gw.csv
# Copying clean_data/2021-22/players/Vladimir_Coufal_418/gw.csv into clean_data/2021-22/DEF/Vladimir_Coufal_418/gw.csv
# Copying clean_data/2021-22/players/Xherdan_Shaqiri_226/gw.csv into clean_data/2021-22/MID/Xherdan_Shaqiri_226/gw.csv
# Copying clean_data/2021-22/players/Rui Pedro_dos Santos Patrício_427/gw.csv into clean_data/2021-22/GK/Rui Pedro_dos Santos Patrício_427/gw.csv
# Copying clean_data/2021-22/players/Mateusz_Klich_186/gw.csv into clean_data/2021-22/MID/Mateusz_Klich_186/gw.csv
# Copying clean_data/2021-22/players/Frederik_Alves_521/gw.csv into clean_data/2021-22/DEF/Frederik_Alves_521/gw.csv
# Copying clean_data/2021-22/players/Stipe_Perica_388/gw.csv into clean_data/2021-22/FWD/Stipe_Perica_388/gw.csv
# Copying clean_data/2021-22/players/Jonjoe_Kenny_502/gw.csv into clean_data/2021-22/DEF/Jonjoe_Kenny_502/gw.csv
# Copying clean_data/2021-22/players/Oliver_Skipp_373/gw.csv into clean_data/2021-22/MID/Oliver_Skipp_373/gw.csv
# Copying clean_data/2021-22/players/Aymeric_Laporte_259/gw.csv into clean_data/2021-22/DEF/Aymeric_Laporte_259/gw.csv
# Copying clean_data/2021-22/players/Wesley_Fofana_220/gw.csv into clean_data/2021-22/DEF/Wesley_Fofana_220/gw.csv
# Copying clean_data/2021-22/players/James_Storer_621/gw.csv into clean_data/2021-22/GK/James_Storer_621/gw.csv
# Copying clean_data/2021-22/players/Maxwell_Haygarth_628/gw.csv into clean_data/2021-22/MID/Maxwell_Haygarth_628/gw.csv
# Copying clean_data/2021-22/players/Willy_Boly_428/gw.csv into clean_data/2021-22/DEF/Willy_Boly_428/gw.csv
# Copying clean_data/2021-22/players/Phil_Jones_632/gw.csv into clean_data/2021-22/DEF/Phil_Jones_632/gw.csv
# Copying clean_data/2021-22/players/Anthony_Elanga_512/gw.csv into clean_data/2021-22/MID/Anthony_Elanga_512/gw.csv
# Copying clean_data/2021-22/players/Patrick_Cutrone_523/gw.csv into clean_data/2021-22/FWD/Patrick_Cutrone_523/gw.csv
# Copying clean_data/2021-22/players/Kyle_Walker-Peters_342/gw.csv into clean_data/2021-22/DEF/Kyle_Walker-Peters_342/gw.csv
# Copying clean_data/2021-22/players/Anthony_Martial_278/gw.csv into clean_data/2021-22/FWD/Anthony_Martial_278/gw.csv
# Copying clean_data/2021-22/players/Karl_Darlow_294/gw.csv into clean_data/2021-22/GK/Karl_Darlow_294/gw.csv
# Copying clean_data/2021-22/players/Taylor_Richards_537/gw.csv into clean_data/2021-22/MID/Taylor_Richards_537/gw.csv
# Copying clean_data/2021-22/players/Evan_Ferguson_655/gw.csv into clean_data/2021-22/FWD/Evan_Ferguson_655/gw.csv
# Copying clean_data/2021-22/players/Ben_Nelson_645/gw.csv into clean_data/2021-22/DEF/Ben_Nelson_645/gw.csv
# Copying clean_data/2021-22/players/Kieran_Dowell_323/gw.csv into clean_data/2021-22/MID/Kieran_Dowell_323/gw.csv
# Copying clean_data/2021-22/players/Jack_Cork_101/gw.csv into clean_data/2021-22/MID/Jack_Cork_101/gw.csv
# Copying clean_data/2021-22/players/Armando_Broja_518/gw.csv into clean_data/2021-22/FWD/Armando_Broja_518/gw.csv
# Copying clean_data/2021-22/players/Marcel_Lavinier_724/gw.csv into clean_data/2021-22/DEF/Marcel_Lavinier_724/gw.csv
# Copying clean_data/2021-22/players/Archie_Gray_658/gw.csv into clean_data/2021-22/MID/Archie_Gray_658/gw.csv
# Copying clean_data/2021-22/players/Konstantinos_Mavropanos_24/gw.csv into clean_data/2021-22/DEF/Konstantinos_Mavropanos_24/gw.csv
# Copying clean_data/2021-22/players/Ivan_Toney_78/gw.csv into clean_data/2021-22/FWD/Ivan_Toney_78/gw.csv
# Copying clean_data/2021-22/players/Jamal_Lewis_311/gw.csv into clean_data/2021-22/DEF/Jamal_Lewis_311/gw.csv
# Copying clean_data/2021-22/players/Maxwel_Cornet_578/gw.csv into clean_data/2021-22/MID/Maxwel_Cornet_578/gw.csv
# Copying clean_data/2021-22/players/Ben_Davies_364/gw.csv into clean_data/2021-22/DEF/Ben_Davies_364/gw.csv
# Copying clean_data/2021-22/players/Joseph_McGlynn_735/gw.csv into clean_data/2021-22/FWD/Joseph_McGlynn_735/gw.csv
# Copying clean_data/2021-22/players/Virgil_van Dijk_229/gw.csv into clean_data/2021-22/DEF/Virgil_van Dijk_229/gw.csv
# Copying clean_data/2021-22/players/Dilan_Markanday_597/gw.csv into clean_data/2021-22/MID/Dilan_Markanday_597/gw.csv
# Copying clean_data/2021-22/players/Ollie_Watkins_40/gw.csv into clean_data/2021-22/FWD/Ollie_Watkins_40/gw.csv
# Copying clean_data/2021-22/players/Rico_Henry_83/gw.csv into clean_data/2021-22/DEF/Rico_Henry_83/gw.csv
# Copying clean_data/2021-22/players/Eberechi_Eze_160/gw.csv into clean_data/2021-22/MID/Eberechi_Eze_160/gw.csv
# Copying clean_data/2021-22/players/Erik_Lamela_356/gw.csv into clean_data/2021-22/MID/Erik_Lamela_356/gw.csv
# Copying clean_data/2021-22/players/Pierluigi_Gollini_486/gw.csv into clean_data/2021-22/GK/Pierluigi_Gollini_486/gw.csv
# Copying clean_data/2021-22/players/Aaron_Cresswell_411/gw.csv into clean_data/2021-22/DEF/Aaron_Cresswell_411/gw.csv
# Copying clean_data/2021-22/players/Emmanuel_Dennis_450/gw.csv into clean_data/2021-22/FWD/Emmanuel_Dennis_450/gw.csv
# Copying clean_data/2021-22/players/Curtis_Jones_244/gw.csv into clean_data/2021-22/MID/Curtis_Jones_244/gw.csv
# Copying clean_data/2021-22/players/Karl_Hein_532/gw.csv into clean_data/2021-22/GK/Karl_Hein_532/gw.csv
# Copying clean_data/2021-22/players/Chem_Campbell_548/gw.csv into clean_data/2021-22/MID/Chem_Campbell_548/gw.csv
# Copying clean_data/2021-22/players/Tom_Heaton_509/gw.csv into clean_data/2021-22/GK/Tom_Heaton_509/gw.csv
# Copying clean_data/2021-22/players/Mohamed Naser_El Sayed Elneny_12/gw.csv into clean_data/2021-22/MID/Mohamed Naser_El Sayed Elneny_12/gw.csv
# Copying clean_data/2021-22/players/Ashley_Fletcher_395/gw.csv into clean_data/2021-22/FWD/Ashley_Fletcher_395/gw.csv
# Copying clean_data/2021-22/players/Haydon_Roberts_560/gw.csv into clean_data/2021-22/DEF/Haydon_Roberts_560/gw.csv
# Copying clean_data/2021-22/players/Issa_Diop_424/gw.csv into clean_data/2021-22/DEF/Issa_Diop_424/gw.csv
# Copying clean_data/2021-22/players/Conor_Hourihane_29/gw.csv into clean_data/2021-22/MID/Conor_Hourihane_29/gw.csv
# Copying clean_data/2021-22/players/Andreas_Pereira_511/gw.csv into clean_data/2021-22/MID/Andreas_Pereira_511/gw.csv
# Copying clean_data/2021-22/players/Ismaila_Sarr_399/gw.csv into clean_data/2021-22/MID/Ismaila_Sarr_399/gw.csv
# Copying clean_data/2021-22/players/Mathias_Jorgensen_594/gw.csv into clean_data/2021-22/DEF/Mathias_Jorgensen_594/gw.csv
# Copying clean_data/2021-22/players/Héctor_Bellerín_9/gw.csv into clean_data/2021-22/DEF/Héctor_Bellerín_9/gw.csv
# Copying clean_data/2021-22/players/Boubakary_Soumaré_458/gw.csv into clean_data/2021-22/MID/Boubakary_Soumaré_458/gw.csv
# Copying clean_data/2021-22/players/Dejan_Kulusevski_701/gw.csv into clean_data/2021-22/MID/Dejan_Kulusevski_701/gw.csv
# Copying clean_data/2021-22/players/Romeo_Lavia_605/gw.csv into clean_data/2021-22/MID/Romeo_Lavia_605/gw.csv
# Copying clean_data/2021-22/players/Aaron_Ramsey_496/gw.csv into clean_data/2021-22/MID/Aaron_Ramsey_496/gw.csv
# Copying clean_data/2021-22/players/Ibrahima_Diallo_349/gw.csv into clean_data/2021-22/MID/Ibrahima_Diallo_349/gw.csv
# Copying clean_data/2021-22/players/Kasey_McAteer_647/gw.csv into clean_data/2021-22/MID/Kasey_McAteer_647/gw.csv
# Copying clean_data/2021-22/players/Raúl_Jiménez_430/gw.csv into clean_data/2021-22/FWD/Raúl_Jiménez_430/gw.csv
# Copying clean_data/2021-22/players/Nathan_Ferguson_161/gw.csv into clean_data/2021-22/DEF/Nathan_Ferguson_161/gw.csv
# Copying clean_data/2021-22/players/Bertrand_Traoré_32/gw.csv into clean_data/2021-22/MID/Bertrand_Traoré_32/gw.csv
# Copying clean_data/2021-22/players/Martin_Kelly_151/gw.csv into clean_data/2021-22/DEF/Martin_Kelly_151/gw.csv
# Copying clean_data/2021-22/players/Samuel_Kalu_698/gw.csv into clean_data/2021-22/MID/Samuel_Kalu_698/gw.csv
# Copying clean_data/2021-22/players/Crysencio_Summerville_551/gw.csv into clean_data/2021-22/MID/Crysencio_Summerville_551/gw.csv
# Copying clean_data/2021-22/players/Dane_Scarlett_520/gw.csv into clean_data/2021-22/FWD/Dane_Scarlett_520/gw.csv
# Copying clean_data/2021-22/players/Pablo_Fornals_423/gw.csv into clean_data/2021-22/MID/Pablo_Fornals_423/gw.csv
# Copying clean_data/2021-22/players/Fabio Henrique_Tavares_232/gw.csv into clean_data/2021-22/MID/Fabio Henrique_Tavares_232/gw.csv
# Copying clean_data/2021-22/players/Björn_Engels_31/gw.csv into clean_data/2021-22/DEF/Björn_Engels_31/gw.csv
# Copying clean_data/2021-22/players/Cenk_Tosun_622/gw.csv into clean_data/2021-22/FWD/Cenk_Tosun_622/gw.csv
# Copying clean_data/2021-22/players/Fernando_Luiz Rosa_453/gw.csv into clean_data/2021-22/MID/Fernando_Luiz Rosa_453/gw.csv
# Copying clean_data/2021-22/players/Billy_Gilmour_145/gw.csv into clean_data/2021-22/MID/Billy_Gilmour_145/gw.csv
# Copying clean_data/2021-22/players/Matt_Doherty_360/gw.csv into clean_data/2021-22/DEF/Matt_Doherty_360/gw.csv
# Copying clean_data/2021-22/players/William_Saliba_27/gw.csv into clean_data/2021-22/DEF/William_Saliba_27/gw.csv
# Copying clean_data/2021-22/players/Ian Carlo_Poveda-Ocampo_195/gw.csv into clean_data/2021-22/MID/Ian Carlo_Poveda-Ocampo_195/gw.csv
# Copying clean_data/2021-22/players/Miguel_Azeez_721/gw.csv into clean_data/2021-22/MID/Miguel_Azeez_721/gw.csv
# Copying clean_data/2021-22/players/Lewis_Richardson_533/gw.csv into clean_data/2021-22/FWD/Lewis_Richardson_533/gw.csv
# Copying clean_data/2021-22/players/Danny_Ward_204/gw.csv into clean_data/2021-22/GK/Danny_Ward_204/gw.csv
# Copying clean_data/2021-22/players/Francisco_Sierralta_396/gw.csv into clean_data/2021-22/DEF/Francisco_Sierralta_396/gw.csv
# Copying clean_data/2021-22/players/Mads_Bech Sørensen_90/gw.csv into clean_data/2021-22/DEF/Mads_Bech Sørensen_90/gw.csv
# Copying clean_data/2021-22/players/James_McArthur_148/gw.csv into clean_data/2021-22/MID/James_McArthur_148/gw.csv
# Copying clean_data/2021-22/players/Harrison_Ashby_617/gw.csv into clean_data/2021-22/DEF/Harrison_Ashby_617/gw.csv
# Copying clean_data/2021-22/players/Andrew_Omobamidele_331/gw.csv into clean_data/2021-22/DEF/Andrew_Omobamidele_331/gw.csv
# Copying clean_data/2021-22/players/Danny_Rose_377/gw.csv into clean_data/2021-22/DEF/Danny_Rose_377/gw.csv
# Copying clean_data/2021-22/players/Willian_Borges Da Silva_3/gw.csv into clean_data/2021-22/MID/Willian_Borges Da Silva_3/gw.csv
# Copying clean_data/2021-22/players/Alphonse_Areola_489/gw.csv into clean_data/2021-22/GK/Alphonse_Areola_489/gw.csv
# Copying clean_data/2021-22/players/Ibrahima_Konaté_243/gw.csv into clean_data/2021-22/DEF/Ibrahima_Konaté_243/gw.csv
# Copying clean_data/2021-22/players/David_Raya Martin_80/gw.csv into clean_data/2021-22/GK/David_Raya Martin_80/gw.csv
# Copying clean_data/2021-22/players/Manuel_Lanzini_416/gw.csv into clean_data/2021-22/MID/Manuel_Lanzini_416/gw.csv
# Copying clean_data/2021-22/players/Gabriel Fernando_de Jesus_263/gw.csv into clean_data/2021-22/FWD/Gabriel Fernando_de Jesus_263/gw.csv
# Copying clean_data/2021-22/players/Salomón_Rondón_591/gw.csv into clean_data/2021-22/FWD/Salomón_Rondón_591/gw.csv
# Copying clean_data/2021-22/players/Aaron_Lennon_575/gw.csv into clean_data/2021-22/MID/Aaron_Lennon_575/gw.csv
# Copying clean_data/2021-22/players/Jeremy_Sarmiento_612/gw.csv into clean_data/2021-22/MID/Jeremy_Sarmiento_612/gw.csv
# Copying clean_data/2021-22/players/Morgan_Gibbs-White_440/gw.csv into clean_data/2021-22/MID/Morgan_Gibbs-White_440/gw.csv
# Copying clean_data/2021-22/players/Lewis_Dunk_59/gw.csv into clean_data/2021-22/DEF/Lewis_Dunk_59/gw.csv
# Copying clean_data/2021-22/players/Mazeed_Ogungbo_719/gw.csv into clean_data/2021-22/DEF/Mazeed_Ogungbo_719/gw.csv
# Copying clean_data/2021-22/players/Michael_Olise_464/gw.csv into clean_data/2021-22/MID/Michael_Olise_464/gw.csv
# Copying clean_data/2021-22/players/Alisson_Ramses Becker_231/gw.csv into clean_data/2021-22/GK/Alisson_Ramses Becker_231/gw.csv
# Copying clean_data/2021-22/players/Michy_Batshuayi_126/gw.csv into clean_data/2021-22/FWD/Michy_Batshuayi_126/gw.csv
# Copying clean_data/2021-22/players/Joachim_Andersen_488/gw.csv into clean_data/2021-22/DEF/Joachim_Andersen_488/gw.csv
# Copying clean_data/2021-22/players/Emil_Krafth_303/gw.csv into clean_data/2021-22/DEF/Emil_Krafth_303/gw.csv
# Copying clean_data/2021-22/players/Armstrong_Oko-Flex_652/gw.csv into clean_data/2021-22/MID/Armstrong_Oko-Flex_652/gw.csv
# Copying clean_data/2021-22/players/Thomas_Partey_15/gw.csv into clean_data/2021-22/MID/Thomas_Partey_15/gw.csv
# Copying clean_data/2021-22/players/John_McGinn_35/gw.csv into clean_data/2021-22/MID/John_McGinn_35/gw.csv
# Copying clean_data/2021-22/players/Todd_Cantwell_325/gw.csv into clean_data/2021-22/MID/Todd_Cantwell_325/gw.csv
# Copying clean_data/2021-22/players/Marc_Guéhi_477/gw.csv into clean_data/2021-22/DEF/Marc_Guéhi_477/gw.csv
# Copying clean_data/2021-22/players/Christoph_Zimmermann_324/gw.csv into clean_data/2021-22/DEF/Christoph_Zimmermann_324/gw.csv
# Copying clean_data/2021-22/players/John_Ruddy_452/gw.csv into clean_data/2021-22/GK/John_Ruddy_452/gw.csv
# Copying clean_data/2021-22/players/Harry_Lewis_637/gw.csv into clean_data/2021-22/GK/Harry_Lewis_637/gw.csv
# Copying clean_data/2021-22/players/Joshua_King_468/gw.csv into clean_data/2021-22/FWD/Joshua_King_468/gw.csv
# Copying clean_data/2021-22/players/Japhet_Tanganga_371/gw.csv into clean_data/2021-22/DEF/Japhet_Tanganga_371/gw.csv
# Copying clean_data/2021-22/players/Kamil_Conteh_669/gw.csv into clean_data/2021-22/MID/Kamil_Conteh_669/gw.csv
# Copying clean_data/2021-22/players/Luka_Milivojevic_152/gw.csv into clean_data/2021-22/MID/Luka_Milivojevic_152/gw.csv
# Copying clean_data/2021-22/players/Ferran_Torres_268/gw.csv into clean_data/2021-22/MID/Ferran_Torres_268/gw.csv
# Copying clean_data/2021-22/players/Milot_Rashica_449/gw.csv into clean_data/2021-22/MID/Milot_Rashica_449/gw.csv
# Copying clean_data/2021-22/players/Philip_Zinckernagel_392/gw.csv into clean_data/2021-22/MID/Philip_Zinckernagel_392/gw.csv
# Copying clean_data/2021-22/players/Pascal_Struijk_198/gw.csv into clean_data/2021-22/DEF/Pascal_Struijk_198/gw.csv
# Copying clean_data/2021-22/players/Marco_Stiepermann_316/gw.csv into clean_data/2021-22/MID/Marco_Stiepermann_316/gw.csv
# Copying clean_data/2021-22/players/Caoimhin_Kelleher_242/gw.csv into clean_data/2021-22/GK/Caoimhin_Kelleher_242/gw.csv
# Copying clean_data/2021-22/players/Timothy_Castagne_209/gw.csv into clean_data/2021-22/DEF/Timothy_Castagne_209/gw.csv
# Copying clean_data/2021-22/players/Reiss_Nelson_531/gw.csv into clean_data/2021-22/MID/Reiss_Nelson_531/gw.csv
# Copying clean_data/2021-22/players/Halil_Dervişoğlu_95/gw.csv into clean_data/2021-22/FWD/Halil_Dervişoğlu_95/gw.csv
# Copying clean_data/2021-22/players/Harry_Maguire_273/gw.csv into clean_data/2021-22/DEF/Harry_Maguire_273/gw.csv
# Copying clean_data/2021-22/players/Steven_Bergwijn_369/gw.csv into clean_data/2021-22/MID/Steven_Bergwijn_369/gw.csv
# Copying clean_data/2021-22/players/Ki-Jana_Hoever_443/gw.csv into clean_data/2021-22/DEF/Ki-Jana_Hoever_443/gw.csv
# Copying clean_data/2021-22/players/Mads_Bidstrup_97/gw.csv into clean_data/2021-22/MID/Mads_Bidstrup_97/gw.csv
# Copying clean_data/2021-22/players/Kjell_Scherpen_476/gw.csv into clean_data/2021-22/GK/Kjell_Scherpen_476/gw.csv
# Copying clean_data/2021-22/players/Steven_Alzate_73/gw.csv into clean_data/2021-22/MID/Steven_Alzate_73/gw.csv
# Copying clean_data/2021-22/players/James_Justin_218/gw.csv into clean_data/2021-22/DEF/James_Justin_218/gw.csv
# Copying clean_data/2021-22/players/Mason_Holgate_178/gw.csv into clean_data/2021-22/DEF/Mason_Holgate_178/gw.csv
# Copying clean_data/2021-22/players/Oriol_Romeu Vidal_335/gw.csv into clean_data/2021-22/MID/Oriol_Romeu Vidal_335/gw.csv
# Copying clean_data/2021-22/players/Vontae_Daley-Campbell_639/gw.csv into clean_data/2021-22/DEF/Vontae_Daley-Campbell_639/gw.csv
# Copying clean_data/2021-22/players/Hassane_Kamara_676/gw.csv into clean_data/2021-22/DEF/Hassane_Kamara_676/gw.csv
# Copying clean_data/2021-22/players/Keinan_Davis_49/gw.csv into clean_data/2021-22/FWD/Keinan_Davis_49/gw.csv
# Copying clean_data/2021-22/players/Juraj_Kucka_495/gw.csv into clean_data/2021-22/MID/Juraj_Kucka_495/gw.csv
# Copying clean_data/2021-22/players/Matthew_Lowton_110/gw.csv into clean_data/2021-22/DEF/Matthew_Lowton_110/gw.csv
# Copying clean_data/2021-22/players/Rob_Holding_14/gw.csv into clean_data/2021-22/DEF/Rob_Holding_14/gw.csv
# Copying clean_data/2021-22/players/Dan_Gosling_378/gw.csv into clean_data/2021-22/MID/Dan_Gosling_378/gw.csv
# Copying clean_data/2021-22/players/Ben_Godfrey_179/gw.csv into clean_data/2021-22/DEF/Ben_Godfrey_179/gw.csv
# Copying clean_data/2021-22/players/Francisco_Femenía Far_382/gw.csv into clean_data/2021-22/DEF/Francisco_Femenía Far_382/gw.csv
# Copying clean_data/2021-22/players/Adam_Idah_329/gw.csv into clean_data/2021-22/FWD/Adam_Idah_329/gw.csv
# Copying clean_data/2021-22/players/Neal_Maupay_63/gw.csv into clean_data/2021-22/FWD/Neal_Maupay_63/gw.csv
# Copying clean_data/2021-22/players/Harry_Winks_366/gw.csv into clean_data/2021-22/MID/Harry_Winks_366/gw.csv
# ...
# Copying clean_data/2020-21/players/Aboubakar_Kamara_190/gw.csv into clean_data/2020-21/MID/Aboubakar_Kamara_190/gw.csv
# Copying clean_data/2020-21/players/Rúnar Alex_Rúnarsson_547/gw.csv into clean_data/2020-21/GK/Rúnar Alex_Rúnarsson_547/gw.csv
# Copying clean_data/2020-21/players/Lucas_Torreira_19/gw.csv into clean_data/2020-21/MID/Lucas_Torreira_19/gw.csv
# Copying clean_data/2020-21/players/Davinson_Sánchez_398/gw.csv into clean_data/2020-21/DEF/Davinson_Sánchez_398/gw.csv
# Copying clean_data/2020-21/players/Ryan_Bennett_456/gw.csv into clean_data/2020-21/DEF/Ryan_Bennett_456/gw.csv
# Copying clean_data/2020-21/players/Pascal_Groß_57/gw.csv into clean_data/2020-21/MID/Pascal_Groß_57/gw.csv
# Copying clean_data/2020-21/players/Alireza_Jahanbakhsh_71/gw.csv into clean_data/2020-21/MID/Alireza_Jahanbakhsh_71/gw.csv
# Copying clean_data/2020-21/players/Kyle_Edwards_421/gw.csv into clean_data/2020-21/MID/Kyle_Edwards_421/gw.csv
# Copying clean_data/2020-21/players/Mbaye_Diagne_648/gw.csv into clean_data/2020-21/FWD/Mbaye_Diagne_648/gw.csv
# Copying clean_data/2020-21/players/Javier_Manquillo_332/gw.csv into clean_data/2020-21/DEF/Javier_Manquillo_332/gw.csv
# Copying clean_data/2020-21/players/Robert_Snodgrass_428/gw.csv into clean_data/2020-21/MID/Robert_Snodgrass_428/gw.csv
# Copying clean_data/2020-21/players/Yan_Valery_378/gw.csv into clean_data/2020-21/DEF/Yan_Valery_378/gw.csv
# Copying clean_data/2020-21/players/Heung-Min_Son_390/gw.csv into clean_data/2020-21/MID/Heung-Min_Son_390/gw.csv
# Copying clean_data/2020-21/players/Thakgalo_Leshabela_661/gw.csv into clean_data/2020-21/MID/Thakgalo_Leshabela_661/gw.csv
# Copying clean_data/2020-21/players/Eberechi_Eze_489/gw.csv into clean_data/2020-21/MID/Eberechi_Eze_489/gw.csv
# Copying clean_data/2020-21/players/Owen_Otasowie_581/gw.csv into clean_data/2020-21/MID/Owen_Otasowie_581/gw.csv
# Copying clean_data/2020-21/players/Sergio_Romero_289/gw.csv into clean_data/2020-21/GK/Sergio_Romero_289/gw.csv
# Copying clean_data/2020-21/players/Nile_John_710/gw.csv into clean_data/2020-21/MID/Nile_John_710/gw.csv
# Copying clean_data/2020-21/players/Filip_Benkovic_237/gw.csv into clean_data/2020-21/DEF/Filip_Benkovic_237/gw.csv
# Copying clean_data/2020-21/players/Olivier_Giroud_103/gw.csv into clean_data/2020-21/FWD/Olivier_Giroud_103/gw.csv
# Copying clean_data/2020-21/players/Sébastien_Haller_441/gw.csv into clean_data/2020-21/FWD/Sébastien_Haller_441/gw.csv
# Copying clean_data/2020-21/players/Lucas_Digne_155/gw.csv into clean_data/2020-21/DEF/Lucas_Digne_155/gw.csv
# Copying clean_data/2020-21/players/Vicente_Guaita_128/gw.csv into clean_data/2020-21/GK/Vicente_Guaita_128/gw.csv
# Copying clean_data/2020-21/players/Christian_Benteke_132/gw.csv into clean_data/2020-21/FWD/Christian_Benteke_132/gw.csv
# Copying clean_data/2020-21/players/Conor_Townsend_418/gw.csv into clean_data/2020-21/DEF/Conor_Townsend_418/gw.csv
# Copying clean_data/2020-21/players/Ivan Ricardo_Neves Abreu Cavaleiro_187/gw.csv into clean_data/2020-21/MID/Ivan Ricardo_Neves Abreu Cavaleiro_187/gw.csv
# Copying clean_data/2020-21/players/Jarrod_Bowen_445/gw.csv into clean_data/2020-21/MID/Jarrod_Bowen_445/gw.csv
# Copying clean_data/2020-21/players/Maxime_Le Marchand_173/gw.csv into clean_data/2020-21/DEF/Maxime_Le Marchand_173/gw.csv
# Copying clean_data/2020-21/players/Tammy_Abraham_118/gw.csv into clean_data/2020-21/FWD/Tammy_Abraham_118/gw.csv
# Copying clean_data/2020-21/players/Ross_Barkley_106/gw.csv into clean_data/2020-21/MID/Ross_Barkley_106/gw.csv
# Copying clean_data/2020-21/players/Kortney_Hause_39/gw.csv into clean_data/2020-21/DEF/Kortney_Hause_39/gw.csv
# Copying clean_data/2020-21/players/Max_Kilman_470/gw.csv into clean_data/2020-21/DEF/Max_Kilman_470/gw.csv
# Copying clean_data/2020-21/players/Georginio_Wijnaldum_243/gw.csv into clean_data/2020-21/MID/Georginio_Wijnaldum_243/gw.csv
# Copying clean_data/2020-21/players/Ahmed_El Mohamady_29/gw.csv into clean_data/2020-21/DEF/Ahmed_El Mohamady_29/gw.csv
# Copying clean_data/2020-21/players/Florin_Andone_64/gw.csv into clean_data/2020-21/FWD/Florin_Andone_64/gw.csv
# Copying clean_data/2020-21/players/Robbie_Brady_95/gw.csv into clean_data/2020-21/MID/Robbie_Brady_95/gw.csv
# Copying clean_data/2020-21/players/Nick_Pope_96/gw.csv into clean_data/2020-21/GK/Nick_Pope_96/gw.csv
# Copying clean_data/2020-21/players/Joel_Matip_246/gw.csv into clean_data/2020-21/DEF/Joel_Matip_246/gw.csv
# Copying clean_data/2020-21/players/Oliver_Burke_424/gw.csv into clean_data/2020-21/MID/Oliver_Burke_424/gw.csv
# Copying clean_data/2020-21/players/Branislav_Ivanovic_530/gw.csv into clean_data/2020-21/DEF/Branislav_Ivanovic_530/gw.csv
# Copying clean_data/2020-21/players/Frederico_Rodrigues de Paula Santos_299/gw.csv into clean_data/2020-21/MID/Frederico_Rodrigues de Paula Santos_299/gw.csv
# Copying clean_data/2020-21/players/DeAndre_Yedlin_335/gw.csv into clean_data/2020-21/DEF/DeAndre_Yedlin_335/gw.csv
# Copying clean_data/2020-21/players/Francisco_Casilla Cortés_194/gw.csv into clean_data/2020-21/GK/Francisco_Casilla Cortés_194/gw.csv
# Copying clean_data/2020-21/players/Grady_Diangana_446/gw.csv into clean_data/2020-21/MID/Grady_Diangana_446/gw.csv
# Copying clean_data/2020-21/players/Paul_Pogba_296/gw.csv into clean_data/2020-21/MID/Paul_Pogba_296/gw.csv
# Copying clean_data/2020-21/players/Valentino_Livramento_698/gw.csv into clean_data/2020-21/DEF/Valentino_Livramento_698/gw.csv
# Copying clean_data/2020-21/players/Xherdan_Shaqiri_247/gw.csv into clean_data/2020-21/MID/Xherdan_Shaqiri_247/gw.csv
# Copying clean_data/2020-21/players/Jordan_Hugill_444/gw.csv into clean_data/2020-21/FWD/Jordan_Hugill_444/gw.csv
# Copying clean_data/2020-21/players/Reda_Khadra_630/gw.csv into clean_data/2020-21/MID/Reda_Khadra_630/gw.csv
# Copying clean_data/2020-21/players/Sidnei_Tavares_676/gw.csv into clean_data/2020-21/MID/Sidnei_Tavares_676/gw.csv
# Copying clean_data/2020-21/players/Facundo_Pellistri_575/gw.csv into clean_data/2020-21/MID/Facundo_Pellistri_575/gw.csv
# Copying clean_data/2020-21/players/Solomon_March_65/gw.csv into clean_data/2020-21/MID/Solomon_March_65/gw.csv
# Copying clean_data/2020-21/players/Michal_Karbownik_663/gw.csv into clean_data/2020-21/DEF/Michal_Karbownik_663/gw.csv
# Copying clean_data/2020-21/players/Callum_Wilson_506/gw.csv into clean_data/2020-21/FWD/Callum_Wilson_506/gw.csv
# Copying clean_data/2020-21/players/Tyrese_Francois_708/gw.csv into clean_data/2020-21/MID/Tyrese_Francois_708/gw.csv
# Copying clean_data/2020-21/players/Jeffrey_Schlupp_142/gw.csv into clean_data/2020-21/MID/Jeffrey_Schlupp_142/gw.csv
# Copying clean_data/2020-21/players/Emerson_Palmieri dos Santos_111/gw.csv into clean_data/2020-21/DEF/Emerson_Palmieri dos Santos_111/gw.csv
# Copying clean_data/2020-21/players/Jacob_Ramsey_554/gw.csv into clean_data/2020-21/MID/Jacob_Ramsey_554/gw.csv
# Copying clean_data/2020-21/players/Mason_Greenwood_315/gw.csv into clean_data/2020-21/MID/Mason_Greenwood_315/gw.csv
# Copying clean_data/2020-21/players/Rhys_Williams_594/gw.csv into clean_data/2020-21/DEF/Rhys_Williams_594/gw.csv
# Copying clean_data/2020-21/players/Jakub_Moder_628/gw.csv into clean_data/2020-21/MID/Jakub_Moder_628/gw.csv
# Copying clean_data/2020-21/players/Richard_Nartey_658/gw.csv into clean_data/2020-21/DEF/Richard_Nartey_658/gw.csv
# Copying clean_data/2020-21/players/Kean_Bryan_603/gw.csv into clean_data/2020-21/DEF/Kean_Bryan_603/gw.csv
# Copying clean_data/2020-21/players/Morgan_Gibbs-White_473/gw.csv into clean_data/2020-21/MID/Morgan_Gibbs-White_473/gw.csv
# Copying clean_data/2020-21/players/Kasper_Schmeichel_217/gw.csv into clean_data/2020-21/GK/Kasper_Schmeichel_217/gw.csv
# Copying clean_data/2020-21/players/Scott_McTominay_309/gw.csv into clean_data/2020-21/MID/Scott_McTominay_309/gw.csv
# Copying clean_data/2020-21/players/David_McGoldrick_344/gw.csv into clean_data/2020-21/FWD/David_McGoldrick_344/gw.csv
# Copying clean_data/2020-21/players/Davy_Pröpper_59/gw.csv into clean_data/2020-21/MID/Davy_Pröpper_59/gw.csv
# Copying clean_data/2020-21/players/Jack_Robinson_352/gw.csv into clean_data/2020-21/DEF/Jack_Robinson_352/gw.csv
# Copying clean_data/2020-21/players/Ferran_Torres_287/gw.csv into clean_data/2020-21/MID/Ferran_Torres_287/gw.csv
# Copying clean_data/2020-21/players/Stefan_Johansen_174/gw.csv into clean_data/2020-21/MID/Stefan_Johansen_174/gw.csv
# Copying clean_data/2020-21/players/Ben_Woodburn_696/gw.csv into clean_data/2020-21/MID/Ben_Woodburn_696/gw.csv
# Copying clean_data/2020-21/players/Mesut_Özil_1/gw.csv into clean_data/2020-21/MID/Mesut_Özil_1/gw.csv
# Copying clean_data/2020-21/players/Tariq_Lamptey_77/gw.csv into clean_data/2020-21/DEF/Tariq_Lamptey_77/gw.csv
# Copying clean_data/2020-21/players/Ashley_Westwood_89/gw.csv into clean_data/2020-21/MID/Ashley_Westwood_89/gw.csv
# Copying clean_data/2020-21/players/Ethan_Ampadu_509/gw.csv into clean_data/2020-21/DEF/Ethan_Ampadu_509/gw.csv
# Copying clean_data/2020-21/players/Danny_Welbeck_588/gw.csv into clean_data/2020-21/FWD/Danny_Welbeck_588/gw.csv
# Copying clean_data/2020-21/players/Lewis_Richards_615/gw.csv into clean_data/2020-21/DEF/Lewis_Richards_615/gw.csv
# Copying clean_data/2020-21/players/Christian_Pulisic_119/gw.csv into clean_data/2020-21/MID/Christian_Pulisic_119/gw.csv
# Copying clean_data/2020-21/players/Sergio_Agüero_268/gw.csv into clean_data/2020-21/FWD/Sergio_Agüero_268/gw.csv
# Copying clean_data/2020-21/players/Harry_Lewis_625/gw.csv into clean_data/2020-21/GK/Harry_Lewis_625/gw.csv
# Copying clean_data/2020-21/players/Ollie_Watkins_514/gw.csv into clean_data/2020-21/FWD/Ollie_Watkins_514/gw.csv
# Copying clean_data/2020-21/players/Willy_Caballero_101/gw.csv into clean_data/2020-21/GK/Willy_Caballero_101/gw.csv
# Copying clean_data/2020-21/players/João Pedro Cavaco_Cancelo_277/gw.csv into clean_data/2020-21/DEF/João Pedro Cavaco_Cancelo_277/gw.csv
# Copying clean_data/2020-21/players/Mohammed_Salisu_479/gw.csv into clean_data/2020-21/DEF/Mohammed_Salisu_479/gw.csv
# Copying clean_data/2020-21/players/Nathan_Broadhead_680/gw.csv into clean_data/2020-21/MID/Nathan_Broadhead_680/gw.csv
# Copying clean_data/2020-21/players/Phil_Jones_297/gw.csv into clean_data/2020-21/DEF/Phil_Jones_297/gw.csv
# Copying clean_data/2020-21/players/Jonas_Lössl_151/gw.csv into clean_data/2020-21/GK/Jonas_Lössl_151/gw.csv
# Copying clean_data/2020-21/players/Vladimir_Coufal_558/gw.csv into clean_data/2020-21/DEF/Vladimir_Coufal_558/gw.csv
# Copying clean_data/2020-21/players/Dwight_Gayle_329/gw.csv into clean_data/2020-21/FWD/Dwight_Gayle_329/gw.csv
# Copying clean_data/2020-21/players/Rayan_Ait Nouri_563/gw.csv into clean_data/2020-21/DEF/Rayan_Ait Nouri_563/gw.csv
# Copying clean_data/2020-21/players/Jesse_Lingard_301/gw.csv into clean_data/2020-21/MID/Jesse_Lingard_301/gw.csv
# Copying clean_data/2020-21/players/Oliver_McBurnie_357/gw.csv into clean_data/2020-21/FWD/Oliver_McBurnie_357/gw.csv
# Copying clean_data/2020-21/players/Jimmy_Dunne_519/gw.csv into clean_data/2020-21/DEF/Jimmy_Dunne_519/gw.csv
# Copying clean_data/2020-21/players/Andriy_Yarmolenko_436/gw.csv into clean_data/2020-21/MID/Andriy_Yarmolenko_436/gw.csv
# Copying clean_data/2020-21/players/Liam_Delap_539/gw.csv into clean_data/2020-21/FWD/Liam_Delap_539/gw.csv
# Copying clean_data/2020-21/players/Eric_Bailly_310/gw.csv into clean_data/2020-21/DEF/Eric_Bailly_310/gw.csv
# Copying clean_data/2020-21/players/Alfie_Devine_650/gw.csv into clean_data/2020-21/MID/Alfie_Devine_650/gw.csv
# Copying clean_data/2020-21/players/Frederik_Alves_637/gw.csv into clean_data/2020-21/DEF/Frederik_Alves_637/gw.csv
# Copying clean_data/2020-21/players/Jamie_Vardy_224/gw.csv into clean_data/2020-21/FWD/Jamie_Vardy_224/gw.csv
# Copying clean_data/2020-21/players/Lewis_Dunk_62/gw.csv into clean_data/2020-21/DEF/Lewis_Dunk_62/gw.csv
# Copying clean_data/2020-21/players/Raúl_Jiménez_460/gw.csv into clean_data/2020-21/FWD/Raúl_Jiménez_460/gw.csv
# Copying clean_data/2020-21/players/Andi_Zeqiri_574/gw.csv into clean_data/2020-21/FWD/Andi_Zeqiri_574/gw.csv
# Copying clean_data/2020-21/players/John_Lundstram_355/gw.csv into clean_data/2020-21/MID/John_Lundstram_355/gw.csv
# Copying clean_data/2020-21/players/Matija_Sarkic_472/gw.csv into clean_data/2020-21/GK/Matija_Sarkic_472/gw.csv
# Copying clean_data/2020-21/players/Ryan_Bertrand_362/gw.csv into clean_data/2020-21/DEF/Ryan_Bertrand_362/gw.csv
# Copying clean_data/2020-21/players/Marcus_Bettinelli_183/gw.csv into clean_data/2020-21/GK/Marcus_Bettinelli_183/gw.csv
# Copying clean_data/2020-21/players/Daniel_Amartey_227/gw.csv into clean_data/2020-21/DEF/Daniel_Amartey_227/gw.csv
# Copying clean_data/2020-21/players/Billy_Gilmour_124/gw.csv into clean_data/2020-21/MID/Billy_Gilmour_124/gw.csv
# Copying clean_data/2020-21/players/Moussa_Djenepo_382/gw.csv into clean_data/2020-21/MID/Moussa_Djenepo_382/gw.csv
# Copying clean_data/2020-21/players/Jack_Wilshere_434/gw.csv into clean_data/2020-21/MID/Jack_Wilshere_434/gw.csv
# Copying clean_data/2020-21/players/Fabio Henrique_Tavares_253/gw.csv into clean_data/2020-21/MID/Fabio Henrique_Tavares_253/gw.csv
# Copying clean_data/2020-21/players/Mason_Holgate_165/gw.csv into clean_data/2020-21/DEF/Mason_Holgate_165/gw.csv
# Copying clean_data/2020-21/players/Jakub_Ojrzynski_678/gw.csv into clean_data/2020-21/GK/Jakub_Ojrzynski_678/gw.csv
# Copying clean_data/2020-21/players/Fraser_Forster_523/gw.csv into clean_data/2020-21/GK/Fraser_Forster_523/gw.csv
# Copying clean_data/2020-21/players/Nathan_Aké_279/gw.csv into clean_data/2020-21/DEF/Nathan_Aké_279/gw.csv
# Copying clean_data/2020-21/players/Tom_Cairney_175/gw.csv into clean_data/2020-21/MID/Tom_Cairney_175/gw.csv
# Copying clean_data/2020-21/players/Moisés_Caicedo_664/gw.csv into clean_data/2020-21/MID/Moisés_Caicedo_664/gw.csv
# Copying clean_data/2020-21/players/Thiago_Thiago_490/gw.csv into clean_data/2020-21/DEF/Thiago_Thiago_490/gw.csv
# Copying clean_data/2020-21/players/Allan_Saint-Maximin_338/gw.csv into clean_data/2020-21/MID/Allan_Saint-Maximin_338/gw.csv
# Copying clean_data/2020-21/players/Aaron_Mooy_60/gw.csv into clean_data/2020-21/MID/Aaron_Mooy_60/gw.csv
# Copying clean_data/2020-21/players/Odion_Ighalo_293/gw.csv into clean_data/2020-21/FWD/Odion_Ighalo_293/gw.csv
# Copying clean_data/2020-21/players/Arthur_Masuaku_442/gw.csv into clean_data/2020-21/DEF/Arthur_Masuaku_442/gw.csv
# Copying clean_data/2020-21/players/Patrick_Bamford_202/gw.csv into clean_data/2020-21/FWD/Patrick_Bamford_202/gw.csv
# Copying clean_data/2020-21/players/Joe_Hart_482/gw.csv into clean_data/2020-21/GK/Joe_Hart_482/gw.csv
# Copying clean_data/2020-21/players/Harry_Boyes_704/gw.csv into clean_data/2020-21/DEF/Harry_Boyes_704/gw.csv
# Copying clean_data/2020-21/players/Ola_Aina_562/gw.csv into clean_data/2020-21/DEF/Ola_Aina_562/gw.csv
# Copying clean_data/2020-21/players/James_Bree_43/gw.csv into clean_data/2020-21/DEF/James_Bree_43/gw.csv
# Copying clean_data/2020-21/players/Felix_Nmecha_609/gw.csv into clean_data/2020-21/MID/Felix_Nmecha_609/gw.csv
# Copying clean_data/2020-21/players/Federico_Fernández_323/gw.csv into clean_data/2020-21/DEF/Federico_Fernández_323/gw.csv
# Copying clean_data/2020-21/players/Marek_Rodák_186/gw.csv into clean_data/2020-21/GK/Marek_Rodák_186/gw.csv
# Copying clean_data/2020-21/players/Brandon_Pierrick_147/gw.csv into clean_data/2020-21/MID/Brandon_Pierrick_147/gw.csv
# Copying clean_data/2020-21/players/Ryan_Fraser_507/gw.csv into clean_data/2020-21/MID/Ryan_Fraser_507/gw.csv
# Copying clean_data/2020-21/players/Andros_Townsend_137/gw.csv into clean_data/2020-21/MID/Andros_Townsend_137/gw.csv
# Copying clean_data/2020-21/players/Erik_Pieters_83/gw.csv into clean_data/2020-21/DEF/Erik_Pieters_83/gw.csv
# Copying clean_data/2020-21/players/Daniel_James_311/gw.csv into clean_data/2020-21/MID/Daniel_James_311/gw.csv
# Copying clean_data/2020-21/players/Tim_Iroegbunam_709/gw.csv into clean_data/2020-21/MID/Tim_Iroegbunam_709/gw.csv
# Copying clean_data/2020-21/players/Pierre-Emile_Højbjerg_396/gw.csv into clean_data/2020-21/MID/Pierre-Emile_Højbjerg_396/gw.csv
# Copying clean_data/2020-21/players/Ryan_Fredericks_438/gw.csv into clean_data/2020-21/DEF/Ryan_Fredericks_438/gw.csv
